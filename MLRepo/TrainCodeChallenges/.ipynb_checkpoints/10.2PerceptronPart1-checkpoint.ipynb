# %% [markdown]
# <b>NNPerceptronModel:</b>
#
# <img src="./NNPerceptronModel.png" align="left" height="500" width="500">
#
# <br/><br/><br/><br/><br/><br/><br/><br/>
# <b>Goal of the notebook:</b>
#
#
# <b>+</b> 1) Create a dataset with random scattered dots and label them with defined rules. <br/>
# <b>+</b> 2) Draw a separate line for this rule <br/>
# <b>+</b> 3) Train the NN to recognize label of test dots by coordinates <br/>
# <b>-</b> 4) Vizualize training process in real time. <br/>
# 5) Include biases and draw separate line in different forms. <br/>
# 6) Draw the perseptron line.

# %%
# %matplotlib notebook

# Import libs
import matplotlib
import matplotlib.axes
import matplotlib.figure
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Perceptron
class PerceptronNN:
    
    def __init__(self, NumberOfInputs):
        
        self.weights = np.random.randn(1,NumberOfInputs)
        
    def FeedForward(self, Dot):
        return ActivationFunction(Dot.inputs @ self.weights.T)
    
    def Train(self, Dot):
        
        guess = self.FeedForward(Dot)
        error = Dot.label - guess
        self.weights += error * Dot.inputs * 0.1
        
    def GetWeights(self):
        return self.weights

# %%
# Single point class
class Point:
    
    def __init__(self, NumberOfInputs):
        
        self.inputs = np.random.rand(NumberOfInputs)
        self.label = 0 if self.inputs[0] <= self.inputs[1] else 1
        
    
# Draw the line based on the current weights
# Formula is weights[0]*x + weights[1]*y + weights[2] = 0
def DrawAdjustedLine(Perceptronn):
    
    # TODO:
    weights = Perceptronn.GetWeights()    
    plt.plot((0,1),(0,1), 'k')
    

# Will redraw existing points with labels predicted by perceptron.
# If predicted label fit actual label - dot will have green edge color
# Otherwise red.
def DrawWithPredictedLabels(Axes, TrainList, Perceptronn, TestList=None):
    
    
    
    for axe in Axes:
        for point in TrainList:
            axe.plot(point.inputs[0], point.inputs[1],
                    'ok',
                    markeredgewidth = 2,
                    markersize = 12,
                    markerfacecolor = 'w' if point.label == 0 else 'k',
                    markeredgecolor = 'g' if Perceptronn.FeedForward(point) == point.label else 'r')

        # Draw separate line
        axe.plot((0,1),(0,1), 'k')
    
    plt.xticks(())
    plt.yticks(())
    fig.canvas.draw()
    
    if TestList != None:
        
        for point in TestList:
            Axes[1].plot(point.inputs[0], point.inputs[1],
                    'ok',
                    markeredgewidth = 2,
                    markersize = 12,
                    markerfacecolor = 'w' if point.label == 0 else 'k',
                    markeredgecolor = 'g' if Perceptronn.FeedForward(point) == point.label else 'r')

        Axes[1].plot((0,1),(0,1), 'k')
        
    def PlotDots(axe):
        
    
def ActivationFunction(sum):
    return 0 if sum < 0.5 else 1

# %%
# Main
# Crate list of dots
TrainList = [Point(2) for i in range(10)]
TestList = [Point(2) for i in range(30)]

Perceptron = PerceptronNN(2)

# Create axes outside the draw function.
fig, axes = plt.subplots(1,2)

# Training
for epoch in range(10):
    for dot in TrainList:
        Perceptron.Train(dot)
        DrawWithPredictedLabels(axes, TrainList, Perceptron)
        
    
DrawWithPredictedLabels(axes, TrainList, Perceptron, TestList)
# DrawWithPredictedLabels(TestList, Perceptron)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-d078bf79f71d> in <module>
#      13     for dot in TrainList:
#      14         Perceptron.Train(dot)
# ---> 15         DrawWithPredictedLabels(axes, TrainList, Perceptron)
#      16
#      17
#
# <ipython-input-36-4f650b073842> in DrawWithPredictedLabels(Axes, TrainList, Perceptronn, TestList)
#      31                     markersize = 12,
#      32                     markerfacecolor = 'w' if point.label == 0 else 'k',
# ---> 33                     markeredgecolor = 'g' if Perceptronn.FeedForward(point) == point.label else 'r')
#      34
#      35         # Draw separate line
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1610
#    1611         for line in self._get_lines(*args, **kwargs):
# -> 1612             self.add_line(line)
#    1613             lines.append(line)
#    1614
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in add_line(self, line)
#    1891         self._set_artist_props(line)
#    1892         if line.get_clip_path() is None:
# -> 1893             line.set_clip_path(self.patch)
#    1894
#    1895         self._update_line_limits(line)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py in set_clip_path(self, path, transform)
#     683         if transform is None:
#     684             if isinstance(path, Rectangle):
# --> 685                 self.clipbox = TransformedBbox(Bbox.unit(),
#     686                                                path.get_transform())
#     687                 self._clippath = None
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\transforms.py in unit()
#     797         (1, 1).
#     798         """
# --> 799         return Bbox(np.array([[0.0, 0.0], [1.0, 1.0]], float))
#     800
#     801     @staticmethod
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\transforms.py in __init__(self, points, **kwargs)
#     779         # default or has been mutated; we store the orig points to
#     780         # support the mutated methods
# --> 781         self._points_orig = self._points.copy()
#     782     if DEBUG:
#     783         ___init__ = __init__
#
# KeyboardInterrupt:
